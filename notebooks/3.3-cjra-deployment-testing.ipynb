# %%
import pandas as pd
from spacey_falcon_9_project.config import processed_dir
from pathlib import Path

# 685,679,668
sample = {
    'launch_designator': [None, None, None],
    'booster_version': ['Falcon 9', 'Falcon 9', 'Falcon 9'],
    'orbit': ['LEO', 'SSO', 'GTO'],
    'mission_type': ['Communications', 'Communications', 'Resupply'],
    'launch_site': ['Space Launch Complex 4E', 'Space Launch Complex 4E', 'Space Launch Complex 40'],
    'landing_success': [True, True, None],
    'landing_type': ['ASDS', 'ASDS', 'GTO'],
    'flights': [19,12,32],
    'reused': [True, True, True],
    'landing_pad': ['OCISLY', 'OCISLY', None],
    'block': ['Block 5', 'Block 5', 'Block 5'],
    'serial': ['B1088','B1097','B1069'],
    'longitude': [-120.611,-120.611,-80.57735736],
    'latitude': [34.632,34.632,28.56194122],
    'reused_count': [18,11,31],
    'payload_mass': [15.525, 13.8, 4.2],
    'launch_date': ['2026-06-6','2026-08-19','2026-07-09'],
    'class': [1,1,0],
    'nearest_highway': [30.520335019763284,30.520335019763284,21.16901309169849],
    'nearest_railway': [1.2527874023926493,1.2527874023926493,21.16901309169849],
    'nearest_coastline': [1.4685310654899448,1.4685310654899448,0.930776727110747]
}

sample_df = pd.DataFrame(sample)
sample_df.to_csv(processed_dir.joinpath('sample_input.csv'), index=False)
